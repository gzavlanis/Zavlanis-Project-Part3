# %% [markdown]
# ## Summary Statistics
#
# Calculate some basic statistics in order to get to know better the dataset

# %%
# !pip install openpyxl
# Out:
# Collecting openpyxl
#   Downloading openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting et-xmlfile (from openpyxl)
#   Downloading et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Downloading openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Downloading et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-2.0.0 openpyxl-3.1.5

# %%
import pandas as pd
import numpy as np

data = pd.read_excel('../Data/grades.xlsx', header = [0, 1]) # load dataset defining the headers
data.columns = [' '.join(col).strip() for col in data.columns.values]
data.replace('-', np.nan, inplace = True) # wrong values to be numeric
data.replace(-1, np.nan, inplace = True)
data.fillna(0, inplace = True)
data = data.loc[:, (data != 0).any(axis = 0)]

# Display summary statistics
summary = data.describe()
print(data.head(10))
print("Summary of the dadaset:")
print(summary)
# Out:
#    Exams Final  Exams Repeat  Homework Assignments 1  Homework Assignments 2  \
# 0         10.0           0.0                    10.0                    10.0
# 1          9.1           0.0                     9.5                     9.6
# 2          9.0           0.0                     9.7                    10.0
# 3          8.8           0.0                     9.1                     8.9
# 4          8.8           0.0                     9.9                     9.6
# 5          8.5           0.0                     8.5                    10.0
# 6          8.5           0.0                     6.3                     9.2
# 7          8.4           0.0                     9.7                     9.8
# 8          8.2           0.0                     8.8                     9.3
# 9          8.1           0.0                     7.8                     8.3
#
#    Homework Assignments 3  Homework Assignments 4  Compulsory Activities 1  \
# 0                    10.0                    10.0                     10.0
# 1                     8.8                    10.0                      7.5
# 2                     9.5                     1.9                     10.0
# 3                     6.0                     0.8                      8.5
# 4                     9.5                    10.0                      9.5
# 5                     8.0                    10.0                      7.5
# 6                     7.3                     5.0                      8.0
# 7                     9.5                     6.0                     10.0
# 8                     9.5                     2.0                      8.5
# 9                     7.4                     6.6                      9.1
#
#    Compulsory Activities 2  Compulsory Activities 3  Compulsory Activities 4  \
# 0                     10.0                     10.0                      9.0
# 1                      9.0                     10.0                      6.0
# 2                      9.0                     10.0                      9.5
# 3                      9.0                     10.0                      8.0
# 4                     10.0                     10.0                      9.0
# 5                      9.5                      9.0                      8.0
# 6                      4.0                      8.0                      8.0
# 7                     10.0                     10.0                     10.0
# 8                     10.0                     10.0                     10.0
# 9                      9.0                      5.0                      6.0
#
#    ...  Optional Activities 1  Optional Activities 2  Optional Activities 3  \
# 0  ...                    5.0                    4.0                    5.0
# 1  ...                    3.5                    4.0                    3.5
# 2  ...                    0.0                    0.0                    0.0
# 3  ...                    2.3                    1.5                    5.0
# 4  ...                    2.5                    1.0                    1.0
# 5  ...                    3.0                    4.0                    3.0
# 6  ...                    3.0                    5.0                    4.3
# 7  ...                    5.0                    5.0                    3.0
# 8  ...                    0.0                    0.0                    4.0
# 9  ...                    1.0                    3.0                    0.0
#
#    Optional Activities 4  Optional Activities 5  Optional Activities 6  \
# 0                    5.0                    4.0                    5.0
# 1                    4.0                    2.0                    4.7
# 2                    0.0                    0.0                    0.0
# 3                    2.0                    2.0                    2.0
# 4                    3.0                    1.0                    5.0
# 5                    4.3                    5.0                    5.0
# 6                    2.0                    3.0                    5.0
# 7                    4.0                    5.0                    5.0
# 8                    2.0                    5.0                    4.0
# 9                    3.0                    2.0                    2.7
#
#    Optional Activities 7  Optional Activities 8  Optional Activities 9  \
# 0                    4.5                    0.0                    0.0
# 1                    3.0                    1.0                    3.0
# 2                    0.0                    0.0                    0.0
# 3                    0.0                    0.0                    0.0
# 4                    0.0                    2.0                    2.0
# 5                    2.0                    3.5                    4.0
# 6                    5.0                    2.5                    0.0
# 7                    5.0                    5.0                    4.0
# 8                    5.0                    0.0                    4.0
# 9                    0.0                    0.0                    0.0
#
#    Optional Activities 10
# 0                     0.0
# 1                     0.0
# 2                     0.0
# 3                     3.0
# 4                     3.0
# 5                     5.0
# 6                     0.0
# 7                     5.0
# 8                     1.0
# 9                     0.0
#
# [10 rows x 24 columns]
# Summary of the dadaset:
#        Exams Final  Exams Repeat  Homework Assignments 1  \
# count   159.000000    159.000000              159.000000
# mean      3.525786      1.046541                7.089937
# std       3.091827      2.094048                2.323986
# min       0.000000      0.000000                0.000000
# 25%       0.000000      0.000000                6.200000
# 50%       3.900000      0.000000                7.700000
# 75%       6.000000      0.000000                8.800000
# max      10.000000      9.100000               10.000000
#
#        Homework Assignments 2  Homework Assignments 3  Homework Assignments 4  \
# count              159.000000              159.000000              159.000000
# mean                 7.273585                6.616981                2.962264
# std                  2.632404                2.509784                3.104054
# min                  0.000000                0.000000                0.000000
# 25%                  7.050000                5.800000                0.400000
# 50%                  8.000000                7.200000                1.900000
# 75%                  8.950000                8.000000                4.900000
# max                 10.000000               10.000000               10.000000
#
#        Compulsory Activities 1  Compulsory Activities 2  \
# count               159.000000               159.000000
# mean                  5.572327                 5.508805
# std                   4.021853                 4.283770
# min                   0.000000                 0.000000
# 25%                   0.000000                 0.000000
# 50%                   7.300000                 7.000000
# 75%                   9.000000                 9.500000
# max                  10.000000                10.000000
#
#        Compulsory Activities 3  Compulsory Activities 4  ...  \
# count               159.000000               159.000000  ...
# mean                  5.578616                 5.616352  ...
# std                   4.238467                 3.812951  ...
# min                   0.000000                 0.000000  ...
# 25%                   0.000000                 0.000000  ...
# 50%                   8.000000                 7.000000  ...
# 75%                   9.000000                 9.000000  ...
# max                  10.000000                10.000000  ...
#
#        Optional Activities 1  Optional Activities 2  Optional Activities 3  \
# count             159.000000             159.000000             159.000000
# mean                1.259119               0.899371               1.172956
# std                 1.673631               1.643726               1.812394
# min                 0.000000               0.000000               0.000000
# 25%                 0.000000               0.000000               0.000000
# 50%                 0.000000               0.000000               0.000000
# 75%                 3.000000               1.000000               2.750000
# max                 5.000000               5.000000               5.000000
#
#        Optional Activities 4  Optional Activities 5  Optional Activities 6  \
# count             159.000000             159.000000             159.000000
# mean                1.233333               0.886792               1.079874
# std                 1.799566               1.555843               1.823468
# min                 0.000000               0.000000               0.000000
# 25%                 0.000000               0.000000               0.000000
# 50%                 0.000000               0.000000               0.000000
# 75%                 3.000000               1.000000               2.000000
# max                 5.000000               5.000000               5.000000
#
#        Optional Activities 7  Optional Activities 8  Optional Activities 9  \
# count             159.000000             159.000000             159.000000
# mean                0.720755               0.588050               0.452830
# std                 1.514532               1.366895               1.220594
# min                 0.000000               0.000000               0.000000
# 25%                 0.000000               0.000000               0.000000
# 50%                 0.000000               0.000000               0.000000
# 75%                 0.000000               0.000000               0.000000
# max                 5.000000               5.000000               5.000000
#
#        Optional Activities 10
# count              159.000000
# mean                 0.402516
# std                  1.226653
# min                  0.000000
# 25%                  0.000000
# 50%                  0.000000
# 75%                  0.000000
# max                  5.000000
#
# [8 rows x 24 columns]
# /tmp/ipykernel_3050952/4137112696.py:6: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data.replace('-', np.nan, inplace = True) # wrong values to be numeric

# %% [markdown]
# ## Make some statistic plots
#
# Create some basic plots of the original dataset.

# %%
import matplotlib.pyplot as plt

# Histogram of Final grades distribution
plt.hist(data['Exams Final'], bins = 10, color = 'blue', alpha = 0.7)
plt.title('Distribution of Final Exam')
plt.xlabel('Grades')
plt.ylabel('Frequency')
plt.show()

# Histogram of Repeated Exams grades distribution
plt.hist(data['Exams Repeat'], bins = 10, color = 'red', alpha = 0.7)
plt.title('Distribution of Repeated Exam')
plt.xlabel('Grades')
plt.ylabel('Frequency')
plt.show()

# Distribution of Exams keeping the greatest score of the two tries
data['Final Exam'] = data[['Exams Final', 'Exams Repeat']].max(axis = 1)
plt.hist(data['Final Exam'], bins = 10, color = 'green', alpha = 0.7)
plt.title('Distribution selecting the Greatest mark')
plt.xlabel('Grades')
plt.ylabel('Frequency')
plt.show()

data.drop(columns = ['Final Exam'], inplace = True) # drop the new column to keep the original dataset again

# %% [markdown]
# ## Make a performance comparison
# Performance comparison using the mean values

# %%
average_grades = data.mean()

average_grades.plot(kind = 'bar', color = 'orange', alpha = 0.8)
plt.title('Average Grades by Activity')
plt.xlabel('Activity')
plt.ylabel('Average Grade')
plt.show()

# %% [markdown]
# ## Scatter plots
# Create some scatterplots to show relationships

# %%
avg_data = data
avg_data["Homework Avg"] = data[[f"Homework Assignments {i}" for i in range(1, 5)]].mean(axis = 1)
avg_data["Compulsory Activities Avg"] = data[[f"Compulsory Activities {i}" for i in range(1, 9)]].mean(axis = 1)
avg_data["Optional Activities Avg"] = data[[f"Optional Activities {i}" for i in range(1, 11)]].mean(axis = 1)
avg_data['Final Exam'] = data[['Exams Final', 'Exams Repeat']].max(axis = 1)

plt.scatter(avg_data['Homework Avg'], avg_data['Final Exam'], alpha = 0.6)
plt.title('Homework Average values vs Final Exams')
plt.xlabel('Homework average grade')
plt.ylabel('Final Exams max grade')
plt.show()

# %%
plt.scatter(avg_data['Compulsory Activities Avg'], avg_data['Final Exam'], alpha = 0.6, color = 'red')
plt.title('Compulsory activities Average values vs Final Exams')
plt.xlabel('Compulsory activities average grade')
plt.ylabel('Final Exams max grade')
plt.show()

# %%
plt.scatter(avg_data['Optional Activities Avg'], avg_data['Final Exam'], alpha = 0.6, color = 'green')
plt.title('Optional activities Average values vs Final Exams')
plt.xlabel('Optional activities average grade')
plt.ylabel('Final Exams max grade')
plt.show()
